# %%
# SINGLE /LINERA REGRESSION

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel(r"C:\Users\ACER\OneDrive\Desktop\ppt\Book1.xlsx")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price,color="red",marker="+")
plt.xlabel("area")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# y = mx+b where m is coef and b is intercept

# %% [markdown]
# price = m* area +b

# %% [markdown]
# y= m*x+b
# y = 135.78767123*3300+180616.43835616432

# %%
y = 135.78767123*3300+180616.43835616432
y
# Out:
# 628715.7534151643

# %% [markdown]
# they are predicting the same value as we can see

# %%
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area,df.price,color="red",marker="*")
plt.plot(df.area,reg.predict(df[["area"]]),color="blue")

# %% [markdown]
# Upto now we are prediting only one area price but below we will give the list ot area size and it will predict at once

# %%
d = pd.read_excel(r"C:\Users\ACER\OneDrive\Desktop\ppt\Book1w.xlsx")

# %%
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p= reg.predict(d)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
d["prices"]= p
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %% [markdown]
# predicting the next income of 2020 from below data

# %%
sales= pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\ppt\canada_per_capita_income.csv")

# %%
sales.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
from sklearn import linear_model

# Assuming df is your DataFrame containing the relevant data
reg = linear_model.LinearRegression()
reg.fit(sales[["year"]], sales["per capita income (US$)"])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])

# %% [markdown]
# here we are predicting for the 2020 year

# %%
#MULTIPLE REGRESSION

# %%
d = pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\ppt\homeprices.csv")

# %%
d
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %% [markdown]
# we need to predict for 3000 sqt,3 bed,40 yrs old
# 2500 sqt,4 bdrooms,5 year old

# %% [markdown]
# price= m1*area+ m2* bedrooms+ m3*age+ b

# %% [markdown]
# we are taking median o bedromms and replace it with NAN

# %%
median_bedrooms = d['bedrooms'].median()
d['bedrooms'].fillna(median_bedrooms, inplace=True)

# %%
d
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg = linear_model.LinearRegression()
reg.fit(d[["area","bedrooms","age"]], d["price"])
# Out:
# LinearRegression()

# %%
reg.predict([[3000,3,40]])
# Out:
# array([498408.25158031])

# %% [markdown]
# here we are  cross checking and we are getting approx same value y= mx+b

# %%
(112.06244194*3000+23388.88007794*3+(-3231.71790863)*40)+221323.0018654043
# Out:
# 498408.2515740243

# %%
(112.06244194*2500+23388.88007794*4+(-3231.71790863)*5)+221323.0018654043
# Out:
# 578876.0374840144

# %%
reg.predict([[2500,4,5]])
# Out:
# array([578876.03748933])

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# 221323.0018654043

# %%
#EXERCIES

# %%
df = pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\ppt\hiring.csv")

# %%
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df["experience"].fillna("zero",inplace= True)

# %%
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
pip install word2number
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.experience = df.experience.apply(w2n.word_to_num)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17696\3776223095.py in ?()
# ----> 1 df.experience = df.experience.apply(w2n.word_to_num)
#       2 df
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'experience'

# %%
import pandas as pd
from word2number import w2n

# %%
med = df['test_score(out of 10)'].median()

# %%
df["test_score(out of 10)"].fillna(med,inplace = True)

# %%
df

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["experience","test_score(out of 10)","interview_score(out of 10)"]], df["salary($)"])

# %%
reg.predict([[2,9,6]])

# %%
reg.predict([[12,10,10]])

# %%
reg.coef_

# %%
reg.intercept_
# Out:
# 221323.0018654043

# %%
(2812.95487627*2+1845.70596798*9+2205.24017467*6)+17737.263464337688
# Out:
# 53205.96797671769

# %%
(2812.95487627*12+1845.70596798*10+2205.24017467*10)+17737.263464337688
# Out:
# 92002.18340607767

# %% [markdown]
# 1 lecture

# %% [markdown]
# expolatery data analysis

# %%
df= pd.read_csv(r"C:\Users\ACER\Downloads\CarsData (2).csv")

# %%
df
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0                I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1               Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2           2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3       Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4             Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 97707         Fiesta  2017  10447    Automatic     8337   Petrol  145  54.3
# 97708       3 Series  2014  14995       Manual    25372   Diesel   30  61.4
# 97709         Fiesta  2017   8950       Manual    19910   Petrol  125  54.3
# 97710          Astra  2017  10700    Automatic    24468   Petrol  125  50.4
# 97711    Grandland X  2019  15798       Manual    10586   Diesel  150  48.7
#
#        engineSize Manufacturer
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97712 entries, 0 to 97711
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         97712 non-null  object
#  1   year          97712 non-null  int64
#  2   price         97712 non-null  int64
#  3   transmission  97712 non-null  object
#  4   mileage       97712 non-null  int64
#  5   fuelType      97712 non-null  object
#  6   tax           97712 non-null  int64
#  7   mpg           97712 non-null  float64
#  8   engineSize    97712 non-null  float64
#  9   Manufacturer  97712 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 7.5+ MB

# %% [markdown]
# converting euro price into rupees

# %%
df["price"] = np.round(df["price"]*90.23,decimals=0)

# %%
df["price"]= df["price"].astype("int",inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df["price"]= df["price"].astype("int",inplace = True)
#
# TypeError: NDFrame.astype() got an unexpected keyword argument 'inplace'

# %%
df.head()
# Out:
#            model  year      price transmission  mileage fuelType  tax   mpg  \
# 0            I10  2017   676274.0       Manual    11630   Petrol  145  60.1
# 1           Polo  2017   991537.0       Manual     9200   Petrol  145  58.9
# 2       2 Series  2019  2525538.0    Semi-Auto     1614   Diesel  145  49.6
# 3   Yeti Outdoor  2017  1127424.0       Manual    30960   Diesel  150  62.8
# 4         Fiesta  2017   721750.0       Manual    19353   Petrol  125  54.3
#
#    engineSize Manufacturer
# 0         1.0       hyundi
# 1         1.0   volkswagen
# 2         2.0          BMW
# 3         2.0        skoda
# 4         1.2         ford

# %%
#miles to km = 1.6093
#gallon to liter = gallon*3.78541
#need to convert mpg to kmpl

# %%
df["kmpl"]=np.round((df["mpg"]*1.6093)/3.78541,decimals =2)

# %%
df.drop("mpg",axis=1,inplace= True)

# %%
df.head()
# Out:
#            model  year      price transmission  mileage fuelType  tax  \
# 0            I10  2017   676274.0       Manual    11630   Petrol  145
# 1           Polo  2017   991537.0       Manual     9200   Petrol  145
# 2       2 Series  2019  2525538.0    Semi-Auto     1614   Diesel  145
# 3   Yeti Outdoor  2017  1127424.0       Manual    30960   Diesel  150
# 4         Fiesta  2017   721750.0       Manual    19353   Petrol  125
#
#    engineSize Manufacturer   kmpl
# 0         1.0       hyundi  25.55
# 1         1.0   volkswagen  25.04
# 2         2.0          BMW  21.09
# 3         2.0        skoda  26.70
# 4         1.2         ford  23.08

# %%
df.drop("mileage",axis =1 ,inplace =True)

# %%
df["model"].value_counts()
# Out:
# model
#  Fiesta     6509
#  Golf       4797
#  Focus      4555
#  C Class    3694
#  Corsa      3285
#             ...
# E Class        1
# 200            1
#  Ranger        1
# 180            1
# 220            1
# Name: count, Length: 196, dtype: int64

# %%
df["Manufacturer"].value_counts()
# Out:
# Manufacturer
# ford          17811
# volkswagen    14893
# vauxhall      13258
# merc          12860
# BMW           10664
# Audi          10565
# toyota         6699
# skoda          6188
# hyundi         4774
# Name: count, dtype: int64

# %%
df[df["Manufacturer"]=="merc"]
# Out:
#             model  year      price transmission fuelType  tax  engineSize  \
# 9         A Class  2017  1578845.0       Manual   Diesel   30         2.1
# 17      GLA Class  2016  1407588.0    Automatic   Diesel   30         2.1
# 32        C Class  2015  1509728.0    Automatic   Diesel   30         2.1
# 49        C Class  2019  2606474.0    Automatic   Diesel  145         2.0
# 50      GLC Class  2018  1881296.0    Automatic   Diesel  150         2.1
# ...           ...   ...        ...          ...      ...  ...         ...
# 97654     C Class  2017  1775726.0    Semi-Auto   Diesel   30         2.1
# 97655   CLA Class  2016  1244723.0    Automatic   Diesel   20         2.1
# 97666     A Class  2016  1316456.0       Manual   Diesel   20         1.5
# 97668    CL Class  2017  1710400.0    Semi-Auto   Diesel   20         2.1
# 97669     C Class  2015  1326201.0    Semi-Auto   Petrol  125         2.0
#
#       Manufacturer   kmpl
# 9             merc  26.70
# ...

# %%
df["fuelType"].value_counts()
# Out:
# fuelType
# Petrol      53982
# Diesel      40419
# Hybrid       3059
# Other         246
# Electric        6
# Name: count, dtype: int64

# %%
df["transmission"].value_counts()
# Out:
# transmission
# Manual       55502
# Semi-Auto    22296
# Automatic    19905
# Other            9
# Name: count, dtype: int64

# %%
df["year"].value_counts().head(10)
# Out:
# year
# 2019    26165
# 2017    21616
# 2016    15724
# 2018    13570
# 2015     7586
# 2014     4053
# 2020     4040
# 2013     2590
# 2012      633
# 2011      432
# Name: count, dtype: int64

# %%
df= df[(df["year"]>=2010)&(df["year"]<2021)]

# %%
df
# Out:
#                model  year      price transmission fuelType  tax  engineSize  \
# 0                I10  2017   676274.0       Manual   Petrol  145         1.0
# 1               Polo  2017   991537.0       Manual   Petrol  145         1.0
# 2           2 Series  2019  2525538.0    Semi-Auto   Diesel  145         2.0
# 3       Yeti Outdoor  2017  1127424.0       Manual   Diesel  150         2.0
# 4             Fiesta  2017   721750.0       Manual   Petrol  125         1.2
# ...              ...   ...        ...          ...      ...  ...         ...
# 97707         Fiesta  2017   942633.0    Automatic   Petrol  145         1.0
# 97708       3 Series  2014  1352999.0       Manual   Diesel   30         2.0
# 97709         Fiesta  2017   807558.0       Manual   Petrol  125         1.2
# 97710          Astra  2017   965461.0    Automatic   Petrol  125         1.4
# 97711    Grandland X  2019  1425454.0       Manual   Diesel  150         1.5
#
#       Manufacturer   kmpl
# ...

# %%
df.reset_index(drop=True)
# Out:
#                model  year      price transmission fuelType  tax  engineSize  \
# 0                I10  2017   676274.0       Manual   Petrol  145         1.0
# 1               Polo  2017   991537.0       Manual   Petrol  145         1.0
# 2           2 Series  2019  2525538.0    Semi-Auto   Diesel  145         2.0
# 3       Yeti Outdoor  2017  1127424.0       Manual   Diesel  150         2.0
# 4             Fiesta  2017   721750.0       Manual   Petrol  125         1.2
# ...              ...   ...        ...          ...      ...  ...         ...
# 96744         Fiesta  2017   942633.0    Automatic   Petrol  145         1.0
# 96745       3 Series  2014  1352999.0       Manual   Diesel   30         2.0
# 96746         Fiesta  2017   807558.0       Manual   Petrol  125         1.2
# 96747          Astra  2017   965461.0    Automatic   Petrol  125         1.4
# 96748    Grandland X  2019  1425454.0       Manual   Diesel  150         1.5
#
#       Manufacturer   kmpl
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96749 entries, 0 to 97711
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         96749 non-null  object
#  1   year          96749 non-null  int64
#  2   price         96749 non-null  float64
#  3   transmission  96749 non-null  object
#  4   fuelType      96749 non-null  object
#  5   tax           96749 non-null  int64
#  6   engineSize    96749 non-null  float64
#  7   Manufacturer  96749 non-null  object
#  8   kmpl          96749 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 7.4+ MB

# %%
np.round(df.groupby("Manufacturer")["price"].mean())
# Out:
# Manufacturer
# Audi          2075405.0
# BMW           2064803.0
# ford          1117720.0
# hyundi        1154258.0
# merc          2239160.0
# skoda         1292800.0
# toyota        1144389.0
# vauxhall       937898.0
# volkswagen    1525453.0
# Name: price, dtype: float64

# %%
np.round(df.groupby("model")["price"].mean().head())
# Out:
# model
# 1 Series    1436165.0
# 2 Series    1754554.0
# 3 Series    1820307.0
# 4 Series    2024940.0
# 5 Series    2049090.0
# Name: price, dtype: float64

# %%
df["model"].unique()
# Out:
# array([' I10', ' Polo', ' 2 Series', ' Yeti Outdoor', ' Fiesta', ' C-HR',
#        ' Kuga', ' Tiguan', ' A Class', ' 1 Series', ' Up', ' Golf',
#        ' Corsa', ' RAV4', ' GLA Class', ' Aygo', ' Q5', ' Karoq',
#        ' Scala', ' Auris', ' Tucson', ' A4', ' Viva', ' Kodiaq',
#        ' C Class', ' Mondeo', ' Citigo', ' Yaris', ' X4', ' Octavia',
#        ' Astra', ' Focus', ' 3 Series', ' GLC Class', ' Q3', ' B-MAX',
#        ' C-MAX', ' IX20', ' X5', ' T-Cross', ' Shuttle', ' Insignia',
#        ' Zafira', ' A3', ' A5', ' SL CLASS', ' EcoSport', ' X1', ' Fabia',
#        ' Golf SV', ' Verso', ' Yeti', ' Mokka X', ' Antara', ' E Class',
#        ' 4 Series', ' Superb', ' 5 Series', ' 8 Series', ' B Class',
#        ' Ka+', ' X2', ' GLE Class', ' A6', ' Mokka', ' Passat', ' Kamiq',
#        ' Adam', ' Q7', ' Tiguan Allspace', ' X3', ' A1', ' Grandland X',
#        ' Meriva', ' Tourneo Connect', ' Arteon', ' TT', ' GLS Class',
# ...

# %% [markdown]
# in used cars the top 10 expensive cars are

# %%
plt.figure(figsize=(12,5))
sns.barplot(np.round(df.groupby("model")["price"].mean().sort_values(ascending = False).head(10)))
# Out:
# <Axes: xlabel='model', ylabel='price'>

# %%
plt.figure(figsize=(12,5))
sns.barplot(np.round(df.groupby("model")["price"].mean().sort_values().head(10)))
# Out:
# <Axes: xlabel='model', ylabel='price'>

# %%
df.groupby(["model","fuelType"])["kmpl"].mean().sort_values(ascending= False).head(10)
# Out:
# model    fuelType
# i3       Other       200.150000
#          Electric    200.150000
#          Hybrid      200.150000
# Ampera   Electric    100.080000
#          Hybrid      100.080000
# Kuga     Hybrid       85.790000
# Superb   Hybrid       81.092222
# A3       Hybrid       74.735333
# E Class  Hybrid       70.660968
# Q7       Hybrid       66.700000
# Name: kmpl, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 mm
#
# NameError: name 'mm' is not defined
